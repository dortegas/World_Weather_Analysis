# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taburbah
# City not found. Skipping...
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | lar
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | husavik
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | churapcha
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | ornskoldsvik
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | batticaloa
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | mount gambier
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | vila franca do campo
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | shirgaon
# Processing Record 23 of Set 1 | batemans bay
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | bubaque
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | sorland
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | mansehra
# Processing Record 36 of Set 1 | port lincoln
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | vijes
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | seymchan
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | derzhavinsk
# Processing Record 46 of Set 1 | erenhot
# Processing Record 47 of Set 1 | hualmay
# Processing Record 48 of Set 1 | praia
# Processing Record 49 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 50 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | mount darwin
# Processing Record 2 of Set 2 | chapais
# Processing Record 3 of Set 2 | amur
# Processing Record 4 of Set 2 | chake chake
# Processing Record 5 of Set 2 | nautla
# Processing Record 6 of Set 2 | talaya
# Processing Record 7 of Set 2 | shingu
# Processing Record 8 of Set 2 | kieta
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | teya
# Processing Record 11 of Set 2 | yulara
# Processing Record 12 of Set 2 | san pedro
# Processing Record 13 of Set 2 | agdangan
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | makakilo city
# Processing Record 16 of Set 2 | seoul
# Processing Record 17 of Set 2 | lagoa
# Processing Record 18 of Set 2 | saint anthony
# Processing Record 19 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 2 | okha
# Processing Record 21 of Set 2 | haimen
# Processing Record 22 of Set 2 | hambantota
# Processing Record 23 of Set 2 | fuyang
# Processing Record 24 of Set 2 | swindon
# Processing Record 25 of Set 2 | pontianak
# Processing Record 26 of Set 2 | westport
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | yuzha
# Processing Record 29 of Set 2 | arman
# Processing Record 30 of Set 2 | pevek
# Processing Record 31 of Set 2 | torbat-e jam
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | balingasay
# Processing Record 35 of Set 2 | morondava
# Processing Record 36 of Set 2 | san cristobal
# Processing Record 37 of Set 2 | coihaique
# Processing Record 38 of Set 2 | eenhana
# Processing Record 39 of Set 2 | puri
# Processing Record 40 of Set 2 | guerrero negro
# Processing Record 41 of Set 2 | muli
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | victoria
# Processing Record 44 of Set 2 | safaga
# Processing Record 45 of Set 2 | narsaq
# Processing Record 46 of Set 2 | dubbo
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | potam
# Processing Record 49 of Set 2 | livadiya
# Processing Record 50 of Set 2 | rio cuarto
# Processing Record 1 of Set 3 | olafsvik
# Processing Record 2 of Set 3 | aksu
# Processing Record 3 of Set 3 | iskateley
# Processing Record 4 of Set 3 | cherskiy
# Processing Record 5 of Set 3 | kushima
# Processing Record 6 of Set 3 | hastings
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | belle fourche
# Processing Record 10 of Set 3 | tadine
# Processing Record 11 of Set 3 | rognan
# Processing Record 12 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 3 | basco
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | priladozhskiy
# Processing Record 16 of Set 3 | bilibino
# Processing Record 17 of Set 3 | samarai
# Processing Record 18 of Set 3 | baykit
# Processing Record 19 of Set 3 | awbari
# Processing Record 20 of Set 3 | karratha
# Processing Record 21 of Set 3 | talcahuano
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | praya
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | elban
# Processing Record 27 of Set 3 | harer
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | tuatapere
# Processing Record 30 of Set 3 | birao
# Processing Record 31 of Set 3 | hirara
# Processing Record 32 of Set 3 | pitsunda
# Processing Record 33 of Set 3 | pitimbu
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | brownwood
# Processing Record 36 of Set 3 | college
# Processing Record 37 of Set 3 | semey
# Processing Record 38 of Set 3 | bibiani
# Processing Record 39 of Set 3 | tiznit
# Processing Record 40 of Set 3 | east london
# Processing Record 41 of Set 3 | gombong
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | avera
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | sola
# Processing Record 47 of Set 3 | patur
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | buala
# Processing Record 50 of Set 3 | agaro
# Processing Record 1 of Set 4 | garmsar
# Processing Record 2 of Set 4 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 3 of Set 4 | kavaratti
# Processing Record 4 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | hinabuyan
# City not found. Skipping...
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | totness
# Processing Record 9 of Set 4 | maceio
# Processing Record 10 of Set 4 | sheridan
# Processing Record 11 of Set 4 | barrow
# Processing Record 12 of Set 4 | talnakh
# Processing Record 13 of Set 4 | padang
# Processing Record 14 of Set 4 | le vauclin
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | de-kastri
# Processing Record 18 of Set 4 | mbini
# Processing Record 19 of Set 4 | cayenne
# Processing Record 20 of Set 4 | santa fe
# Processing Record 21 of Set 4 | khani
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | caravelas
# Processing Record 24 of Set 4 | comodoro rivadavia
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | tiksi
# Processing Record 27 of Set 4 | ponta delgada
# Processing Record 28 of Set 4 | nikolskoye
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | yuryevets
# Processing Record 31 of Set 4 | bertogne
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | ankpa
# Processing Record 34 of Set 4 | chaykovskiy
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | batasan
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | kahului
# Processing Record 40 of Set 4 | bilma
# Processing Record 41 of Set 4 | kharovsk
# Processing Record 42 of Set 4 | grindavik
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | san isidro
# Processing Record 46 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 4 | mlowo
# Processing Record 48 of Set 4 | jalingo
# Processing Record 49 of Set 4 | alghero
# Processing Record 50 of Set 4 | padilla
# Processing Record 1 of Set 5 | saint george
# Processing Record 2 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 5 | arawa
# Processing Record 4 of Set 5 | warrnambool
# Processing Record 5 of Set 5 | saint-augustin
# Processing Record 6 of Set 5 | berlevag
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | keuruu
# Processing Record 9 of Set 5 | haines junction
# Processing Record 10 of Set 5 | kavieng
# Processing Record 11 of Set 5 | tabuk
# Processing Record 12 of Set 5 | do gonbadan
# Processing Record 13 of Set 5 | znamenskoye
# Processing Record 14 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 5 | titlagarh
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | margate
# Processing Record 18 of Set 5 | inuvik
# Processing Record 19 of Set 5 | taoudenni
# Processing Record 20 of Set 5 | fort nelson
# Processing Record 21 of Set 5 | los llanos de aridane
# Processing Record 22 of Set 5 | torbay
# Processing Record 23 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 5 | mayor pablo lagerenza
# Processing Record 25 of Set 5 | acapulco
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | jiuquan
# Processing Record 28 of Set 5 | naze
# Processing Record 29 of Set 5 | odienne
# Processing Record 30 of Set 5 | moissac
# Processing Record 31 of Set 5 | semporna
# Processing Record 32 of Set 5 | yambio
# Processing Record 33 of Set 5 | port hawkesbury
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | elat
# Processing Record 36 of Set 5 | alugan
# Processing Record 37 of Set 5 | copacabana
# Processing Record 38 of Set 5 | hithadhoo
# Processing Record 39 of Set 5 | inhambupe
# Processing Record 40 of Set 5 | waynesville
# Processing Record 41 of Set 5 | katsuura
# Processing Record 42 of Set 5 | hobart
# Processing Record 43 of Set 5 | copiapo
# Processing Record 44 of Set 5 | saskylakh
# Processing Record 45 of Set 5 | tulle
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | bushehr
# Processing Record 48 of Set 5 | tasiilaq
# Processing Record 49 of Set 5 | rock sound
# Processing Record 50 of Set 5 | ustrzyki dolne
# Processing Record 1 of Set 6 | severnyy
# Processing Record 2 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 6 | rapid valley
# Processing Record 5 of Set 6 | tual
# Processing Record 6 of Set 6 | san policarpo
# Processing Record 7 of Set 6 | winnemucca
# Processing Record 8 of Set 6 | karaton
# Processing Record 9 of Set 6 | usinsk
# Processing Record 10 of Set 6 | zhezkazgan
# Processing Record 11 of Set 6 | georgetown
# Processing Record 12 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 6 | bairiki
# Processing Record 14 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 6 | port charlotte
# Processing Record 16 of Set 6 | trujillo
# Processing Record 17 of Set 6 | nogliki
# Processing Record 18 of Set 6 | mackay
# Processing Record 19 of Set 6 | port hardy
# Processing Record 20 of Set 6 | saint-joseph
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | sindor
# Processing Record 23 of Set 6 | yinchuan
# Processing Record 24 of Set 6 | skelleftea
# Processing Record 25 of Set 6 | beltinci
# Processing Record 26 of Set 6 | wakkanai
# Processing Record 27 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 6 | virginia beach
# Processing Record 29 of Set 6 | beringovskiy
# Processing Record 30 of Set 6 | georgiyevka
# Processing Record 31 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 6 | bengkulu
# Processing Record 33 of Set 6 | pochutla
# Processing Record 34 of Set 6 | sucua
# Processing Record 35 of Set 6 | sao jose do belmonte
# Processing Record 36 of Set 6 | hervey bay
# Processing Record 37 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 6 | mecca
# Processing Record 39 of Set 6 | zeya
# Processing Record 40 of Set 6 | piombino
# Processing Record 41 of Set 6 | christchurch
# Processing Record 42 of Set 6 | zaysan
# Processing Record 43 of Set 6 | ahipara
# Processing Record 44 of Set 6 | gamba
# Processing Record 45 of Set 6 | senmonorom
# City not found. Skipping...
# Processing Record 46 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 6 | fomboni
# Processing Record 48 of Set 6 | gazli
# Processing Record 49 of Set 6 | mandali
# Processing Record 50 of Set 6 | chara
# Processing Record 1 of Set 7 | bac lieu
# Processing Record 2 of Set 7 | rio verde de mato grosso
# Processing Record 3 of Set 7 | mahajanga
# Processing Record 4 of Set 7 | alice springs
# Processing Record 5 of Set 7 | lardos
# Processing Record 6 of Set 7 | pacific grove
# Processing Record 7 of Set 7 | koungou
# Processing Record 8 of Set 7 | vanavara
# Processing Record 9 of Set 7 | port elizabeth
# Processing Record 10 of Set 7 | manaus
# Processing Record 11 of Set 7 | ancud
# Processing Record 12 of Set 7 | iberia
# Processing Record 13 of Set 7 | srednekolymsk
# Processing Record 14 of Set 7 | san jose
# Processing Record 15 of Set 7 | tirunelveli
# Processing Record 16 of Set 7 | sonepur
# Processing Record 17 of Set 7 | pangnirtung
# Processing Record 18 of Set 7 | kjopsvik
# Processing Record 19 of Set 7 | kensington
# Processing Record 20 of Set 7 | esperance
# Processing Record 21 of Set 7 | palmaner
# Processing Record 22 of Set 7 | poum
# Processing Record 23 of Set 7 | yanam
# Processing Record 24 of Set 7 | matara
# Processing Record 25 of Set 7 | orikhiv
# Processing Record 26 of Set 7 | starachowice
# Processing Record 27 of Set 7 | fairbanks
# Processing Record 28 of Set 7 | angoche
# Processing Record 29 of Set 7 | colares
# Processing Record 30 of Set 7 | armidale
# Processing Record 31 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 7 | palmer
# Processing Record 33 of Set 7 | dandong
# Processing Record 34 of Set 7 | los algarrobos
# Processing Record 35 of Set 7 | dunedin
# Processing Record 36 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 7 | nova olinda do norte
# Processing Record 38 of Set 7 | acari
# Processing Record 39 of Set 7 | aloleng
# Processing Record 40 of Set 7 | akdepe
# Processing Record 41 of Set 7 | mingguang
# Processing Record 42 of Set 7 | waddan
# Processing Record 43 of Set 7 | storm lake
# Processing Record 44 of Set 7 | trinidad
# Processing Record 45 of Set 7 | lokosovo
# Processing Record 46 of Set 7 | araguaina
# Processing Record 47 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 49 of Set 7 | kiama
# Processing Record 50 of Set 7 | nipawin
# Processing Record 1 of Set 8 | saint-louis
# Processing Record 2 of Set 8 | laguna
# Processing Record 3 of Set 8 | tucurui
# Processing Record 4 of Set 8 | ribeira grande
# Processing Record 5 of Set 8 | flin flon
# Processing Record 6 of Set 8 | ulladulla
# Processing Record 7 of Set 8 | geraldton
# Processing Record 8 of Set 8 | yaan
# Processing Record 9 of Set 8 | bonavista
# Processing Record 10 of Set 8 | marawi
# Processing Record 11 of Set 8 | provideniya
# Processing Record 12 of Set 8 | sitka
# Processing Record 13 of Set 8 | ocos
# Processing Record 14 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 8 | chicama
# Processing Record 16 of Set 8 | katiola
# Processing Record 17 of Set 8 | marsassoum
# Processing Record 18 of Set 8 | poretskoye
# Processing Record 19 of Set 8 | sioux lookout
# Processing Record 20 of Set 8 | jamame
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | mayo
# Processing Record 23 of Set 8 | ahuimanu
# Processing Record 24 of Set 8 | susangerd
# Processing Record 25 of Set 8 | altus
# Processing Record 26 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 27 of Set 8 | hammerfest
# Processing Record 28 of Set 8 | mbour
# Processing Record 29 of Set 8 | yakeshi
# Processing Record 30 of Set 8 | tshane
# Processing Record 31 of Set 8 | aripuana
# Processing Record 32 of Set 8 | yangambi
# Processing Record 33 of Set 8 | salihli
# Processing Record 34 of Set 8 | mariental
# Processing Record 35 of Set 8 | hvide sande
# Processing Record 36 of Set 8 | erdenet
# Processing Record 37 of Set 8 | sain alto
# Processing Record 38 of Set 8 | bereda
# Processing Record 39 of Set 8 | nha trang
# Processing Record 40 of Set 8 | lucatan
# City not found. Skipping...
# Processing Record 41 of Set 8 | north platte
# Processing Record 42 of Set 8 | tombouctou
# Processing Record 43 of Set 8 | hasaki
# Processing Record 44 of Set 8 | aswan
# Processing Record 45 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 46 of Set 8 | nyuksenitsa
# Processing Record 47 of Set 8 | chokwe
# Processing Record 48 of Set 8 | beloha
# Processing Record 49 of Set 8 | hokitika
# Processing Record 50 of Set 8 | republic
# Processing Record 1 of Set 9 | quimper
# Processing Record 2 of Set 9 | carayao
# Processing Record 3 of Set 9 | pushkino
# Processing Record 4 of Set 9 | saldanha
# Processing Record 5 of Set 9 | maltahohe
# Processing Record 6 of Set 9 | aasiaat
# Processing Record 7 of Set 9 | caetite
# Processing Record 8 of Set 9 | bloomingdale
# Processing Record 9 of Set 9 | mehamn
# Processing Record 10 of Set 9 | kapit
# Processing Record 11 of Set 9 | moose factory
# Processing Record 12 of Set 9 | northam
# Processing Record 13 of Set 9 | garowe
# Processing Record 14 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 9 | paamiut
# Processing Record 16 of Set 9 | saint-georges
# Processing Record 17 of Set 9 | shangzhi
# Processing Record 18 of Set 9 | te anau
# Processing Record 19 of Set 9 | mandalgovi
# Processing Record 20 of Set 9 | tondano
# Processing Record 21 of Set 9 | abashiri
# Processing Record 22 of Set 9 | svetlogorsk
# Processing Record 23 of Set 9 | evensk
# Processing Record 24 of Set 9 | eureka
# Processing Record 25 of Set 9 | havoysund
# Processing Record 26 of Set 9 | pahrump
# Processing Record 27 of Set 9 | biak
# Processing Record 28 of Set 9 | okato
# Processing Record 29 of Set 9 | hamilton
# Processing Record 30 of Set 9 | vila velha
# Processing Record 31 of Set 9 | vostok
# Processing Record 32 of Set 9 | noumea
# Processing Record 33 of Set 9 | laviana
# Processing Record 34 of Set 9 | ambanja
# Processing Record 35 of Set 9 | leningradskiy
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | mantua
# Processing Record 38 of Set 9 | antofagasta
# Processing Record 39 of Set 9 | lazaro cardenas
# Processing Record 40 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 41 of Set 9 | bambanglipuro
# Processing Record 42 of Set 9 | punta cardon
# Processing Record 43 of Set 9 | kijang
# Processing Record 44 of Set 9 | abu dhabi
# Processing Record 45 of Set 9 | sawakin
# Processing Record 46 of Set 9 | araouane
# Processing Record 47 of Set 9 | emba
# Processing Record 48 of Set 9 | namibe
# Processing Record 49 of Set 9 | peterlee
# Processing Record 50 of Set 9 | sao filipe
# Processing Record 1 of Set 10 | tezu
# Processing Record 2 of Set 10 | kawalu
# Processing Record 3 of Set 10 | sorong
# Processing Record 4 of Set 10 | atka
# City not found. Skipping...
# Processing Record 5 of Set 10 | melville
# Processing Record 6 of Set 10 | kaoma
# Processing Record 7 of Set 10 | oktyabrskiy
# Processing Record 8 of Set 10 | fortuna
# Processing Record 9 of Set 10 | odessa
# Processing Record 10 of Set 10 | sarakhs
# Processing Record 11 of Set 10 | zenzeli
# Processing Record 12 of Set 10 | port-gentil
# Processing Record 13 of Set 10 | ostrovnoy
# Processing Record 14 of Set 10 | honiara
# Processing Record 15 of Set 10 | karpogory
# Processing Record 16 of Set 10 | shar
# Processing Record 17 of Set 10 | hofn
# Processing Record 18 of Set 10 | constitucion
# Processing Record 19 of Set 10 | vilhena
# Processing Record 20 of Set 10 | sao paulo de olivenca
# Processing Record 21 of Set 10 | pachino
# Processing Record 22 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 10 | novyy urgal
# Processing Record 24 of Set 10 | ketchikan
# Processing Record 25 of Set 10 | mangan
# Processing Record 26 of Set 10 | tieli
# Processing Record 27 of Set 10 | chernyshevskiy
# Processing Record 28 of Set 10 | lorengau
# Processing Record 29 of Set 10 | auki
# Processing Record 30 of Set 10 | jiwani
# Processing Record 31 of Set 10 | tabas
# Processing Record 32 of Set 10 | zhigansk
# Processing Record 33 of Set 10 | vardo
# Processing Record 34 of Set 10 | qafsah
# City not found. Skipping...
# Processing Record 35 of Set 10 | huddersfield
# Processing Record 36 of Set 10 | tonj
# Processing Record 37 of Set 10 | dudinka
# Processing Record 38 of Set 10 | huarmey
# Processing Record 39 of Set 10 | cochabamba
# Processing Record 40 of Set 10 | ginda
# Processing Record 41 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 42 of Set 10 | moose jaw
# Processing Record 43 of Set 10 | delta del tigre
# Processing Record 44 of Set 10 | tilichiki
# Processing Record 45 of Set 10 | yumen
# Processing Record 46 of Set 10 | benghazi
# Processing Record 47 of Set 10 | otane
# Processing Record 48 of Set 10 | ambon
# Processing Record 49 of Set 10 | sao joao da barra
# Processing Record 50 of Set 10 | nelson
# Processing Record 1 of Set 11 | sibolga
# Processing Record 2 of Set 11 | gunjur
# Processing Record 3 of Set 11 | bhairab bazar
# Processing Record 4 of Set 11 | payo
# Processing Record 5 of Set 11 | alofi
# Processing Record 6 of Set 11 | oksovskiy
# Processing Record 7 of Set 11 | vanderhoof
# Processing Record 8 of Set 11 | ujjain
# Processing Record 9 of Set 11 | alta floresta
# Processing Record 10 of Set 11 | blackwater
# Processing Record 11 of Set 11 | beira
# Processing Record 12 of Set 11 | dovolnoye
# Processing Record 13 of Set 11 | ixtapa
# Processing Record 14 of Set 11 | argenta
# Processing Record 15 of Set 11 | lichinga
# Processing Record 16 of Set 11 | phuket
# Processing Record 17 of Set 11 | moron
# Processing Record 18 of Set 11 | spokane
# Processing Record 19 of Set 11 | the valley
# Processing Record 20 of Set 11 | eston
# Processing Record 21 of Set 11 | izhma
# Processing Record 22 of Set 11 | nkhata bay
# Processing Record 23 of Set 11 | tongzi
# Processing Record 24 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 11 | cumra
# Processing Record 26 of Set 11 | nome
# Processing Record 27 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 11 | elizabethtown
# Processing Record 29 of Set 11 | iquitos
# Processing Record 30 of Set 11 | galiakot
# Processing Record 31 of Set 11 | cadiz
# Processing Record 32 of Set 11 | tecpan
# Processing Record 33 of Set 11 | alappuzha
# Processing Record 34 of Set 11 | tuy hoa
# Processing Record 35 of Set 11 | tubuala
# Processing Record 36 of Set 11 | da nang
# Processing Record 37 of Set 11 | kristiansund
# Processing Record 38 of Set 11 | kolvereid
# Processing Record 39 of Set 11 | vao
# Processing Record 40 of Set 11 | el tigre
# Processing Record 41 of Set 11 | gijon
# Processing Record 42 of Set 11 | hay river
# Processing Record 43 of Set 11 | ikirun
# Processing Record 44 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 11 | wanlaweyn
# Processing Record 46 of Set 11 | revelstoke
# Processing Record 47 of Set 11 | port-cartier
# Processing Record 48 of Set 11 | adrar
# Processing Record 49 of Set 11 | afanasyevo
# City not found. Skipping...
# Processing Record 50 of Set 11 | aksarka
# Processing Record 1 of Set 12 | xiaoweizhai
# Processing Record 2 of Set 12 | clyde river
# Processing Record 3 of Set 12 | barcelos
# Processing Record 4 of Set 12 | fukue
# Processing Record 5 of Set 12 | san patricio
# Processing Record 6 of Set 12 | kokoda
# Processing Record 7 of Set 12 | camacupa
# Processing Record 8 of Set 12 | catole do rocha
# Processing Record 9 of Set 12 | donaueschingen
# Processing Record 10 of Set 12 | mangrol
# Processing Record 11 of Set 12 | gorontalo
# Processing Record 12 of Set 12 | mareeba
# Processing Record 13 of Set 12 | mana
# Processing Record 14 of Set 12 | noramarg
# Processing Record 15 of Set 12 | thinadhoo
# Processing Record 16 of Set 12 | broome
# Processing Record 17 of Set 12 | xining
# Processing Record 18 of Set 12 | tautira
# Processing Record 19 of Set 12 | taltal
# Processing Record 20 of Set 12 | plavsk
# Processing Record 21 of Set 12 | arlit
# Processing Record 22 of Set 12 | cap malheureux
# Processing Record 23 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 12 | kysyl-syr
# Processing Record 25 of Set 12 | tazmalt
# Processing Record 26 of Set 12 | jalu
# Processing Record 27 of Set 12 | olinda
# Processing Record 28 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 29 of Set 12 | amasia
# Processing Record 30 of Set 12 | santa rosa
# Processing Record 31 of Set 12 | belmonte
# Processing Record 32 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 12 | mocuba
# Processing Record 34 of Set 12 | kedrovyy
# Processing Record 35 of Set 12 | msowero
# Processing Record 36 of Set 12 | rocky mount
# Processing Record 37 of Set 12 | demir kapija
# Processing Record 38 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 12 | vila
# Processing Record 40 of Set 12 | champerico
# Processing Record 41 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 12 | peleduy
# Processing Record 43 of Set 12 | tongren
# Processing Record 44 of Set 12 | jumla
# Processing Record 45 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 12 | krutinka
# Processing Record 47 of Set 12 | sao sebastiao
# Processing Record 48 of Set 12 | srandakan
# Processing Record 49 of Set 12 | nouadhibou
# Processing Record 50 of Set 12 | cheney
# Processing Record 1 of Set 13 | svetlyy
# Processing Record 2 of Set 13 | ulaangom
# Processing Record 3 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 4 of Set 13 | lompoc
# Processing Record 5 of Set 13 | odweyne
# Processing Record 6 of Set 13 | tarakan
# Processing Record 7 of Set 13 | nakasongola
# Processing Record 8 of Set 13 | sumbe
# Processing Record 9 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 13 | norman wells
# Processing Record 11 of Set 13 | ozernovskiy
# Processing Record 12 of Set 13 | myingyan
# Processing Record 13 of Set 13 | rocha
# Processing Record 14 of Set 13 | nakamura
# Processing Record 15 of Set 13 | cuamba
# Processing Record 16 of Set 13 | duluth
# Processing Record 17 of Set 13 | curico
# Processing Record 18 of Set 13 | upata
# Processing Record 19 of Set 13 | havre-saint-pierre
# Processing Record 20 of Set 13 | crotone
# Processing Record 21 of Set 13 | boyolangu
# Processing Record 22 of Set 13 | bongor
# Processing Record 23 of Set 13 | grand gaube
# Processing Record 24 of Set 13 | puerto carreno
# Processing Record 25 of Set 13 | voh
# Processing Record 26 of Set 13 | morant bay
# Processing Record 27 of Set 13 | paita
# Processing Record 28 of Set 13 | liberal
# Processing Record 29 of Set 13 | goderich
# Processing Record 30 of Set 13 | lagos
# Processing Record 31 of Set 13 | ullapool
# Processing Record 32 of Set 13 | channel-port aux basques
# Processing Record 33 of Set 13 | savannah bight
# Processing Record 34 of Set 13 | sokone
# Processing Record 35 of Set 13 | puerto ayacucho
# Processing Record 36 of Set 13 | fare
# Processing Record 37 of Set 13 | akyab
# Processing Record 38 of Set 13 | kuppam
# Processing Record 39 of Set 13 | ust-nera
# Processing Record 40 of Set 13 | creel
# Processing Record 41 of Set 13 | taucha
# Processing Record 42 of Set 13 | lano
# Processing Record 43 of Set 13 | porosozero
# Processing Record 44 of Set 13 | kasongo-lunda
# Processing Record 45 of Set 13 | victor harbor
# Processing Record 46 of Set 13 | bure
# Processing Record 47 of Set 13 | nuuk
# Processing Record 48 of Set 13 | natal
# Processing Record 49 of Set 13 | princeton
# Processing Record 50 of Set 13 | itarema
# Processing Record 1 of Set 14 | altopascio
# Processing Record 2 of Set 14 | itaituba
# Processing Record 3 of Set 14 | preobrazheniye
# Processing Record 4 of Set 14 | micoud
# Processing Record 5 of Set 14 | guaraniacu
# Processing Record 6 of Set 14 | skjervoy
# Processing Record 7 of Set 14 | salta
# Processing Record 8 of Set 14 | kitgum
# Processing Record 9 of Set 14 | coquimbo
# Processing Record 10 of Set 14 | puerto madryn
# Processing Record 11 of Set 14 | sterling
# Processing Record 12 of Set 14 | north bend
# Processing Record 13 of Set 14 | guanambi
# Processing Record 14 of Set 14 | pemangkat
# Processing Record 15 of Set 14 | nicoya
# Processing Record 16 of Set 14 | port hedland
# Processing Record 17 of Set 14 | marquette
# Processing Record 18 of Set 14 | yenagoa
# Processing Record 19 of Set 14 | deniliquin
# Processing Record 20 of Set 14 | urengoy
# Processing Record 21 of Set 14 | ahar
# Processing Record 22 of Set 14 | mount isa
# Processing Record 23 of Set 14 | calbuco
# Processing Record 24 of Set 14 | krasnoselkup
# Processing Record 25 of Set 14 | vicosa do ceara
# Processing Record 26 of Set 14 | manavalakurichi
# Processing Record 27 of Set 14 | casambalangan
# Processing Record 28 of Set 14 | simbahan
# Processing Record 29 of Set 14 | gat
# Processing Record 30 of Set 14 | smirnykh
# Processing Record 31 of Set 14 | mopipi
# Processing Record 32 of Set 14 | monrovia
# Processing Record 33 of Set 14 | yuanping
# Processing Record 34 of Set 14 | bykovo
# Processing Record 35 of Set 14 | soderhamn
# Processing Record 36 of Set 14 | escarcega
# Processing Record 37 of Set 14 | kapuskasing
# Processing Record 38 of Set 14 | itoman
# Processing Record 39 of Set 14 | maymyo
# Processing Record 40 of Set 14 | luena
# Processing Record 41 of Set 14 | tamworth
# Processing Record 42 of Set 14 | namatanai
# Processing Record 43 of Set 14 | diglur
# Processing Record 44 of Set 14 | puerto colombia
# Processing Record 45 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 46 of Set 14 | bani
# Processing Record 47 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 14 | asau
# Processing Record 49 of Set 14 | cueramaro
# Processing Record 50 of Set 14 | oytal
# Processing Record 1 of Set 15 | gorshechnoye
# Processing Record 2 of Set 15 | gao
# Processing Record 3 of Set 15 | maniitsoq
# Processing Record 4 of Set 15 | plettenberg bay
# Processing Record 5 of Set 15 | am timan
# Processing Record 6 of Set 15 | hanzhong
# Processing Record 7 of Set 15 | shebalino
# Processing Record 8 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 15 | killybegs
# Processing Record 10 of Set 15 | whitehorse
# Processing Record 11 of Set 15 | tres arroyos
# Processing Record 12 of Set 15 | hami
# Processing Record 13 of Set 15 | astana
# Processing Record 14 of Set 15 | tashtyp
# Processing Record 15 of Set 15 | mugumu
# Processing Record 16 of Set 15 | kropotkin
# Processing Record 17 of Set 15 | belize
# Processing Record 18 of Set 15 | ambulu
# Processing Record 19 of Set 15 | bahia honda
# Processing Record 20 of Set 15 | bakchar
# Processing Record 21 of Set 15 | portland
# Processing Record 22 of Set 15 | riyadh
# Processing Record 23 of Set 15 | doka
# Processing Record 24 of Set 15 | bandarbeyla
# Processing Record 25 of Set 15 | sao caetano de odivelas
# Processing Record 26 of Set 15 | satipo
# Processing Record 27 of Set 15 | artyom
# Processing Record 28 of Set 15 | muros
# Processing Record 29 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 15 | narasannapeta
# Processing Record 31 of Set 15 | junnar
# Processing Record 32 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 15 | strezhevoy
# Processing Record 34 of Set 15 | pachora
# Processing Record 35 of Set 15 | rive-de-gier
# Processing Record 36 of Set 15 | villa maria
# Processing Record 37 of Set 15 | nantucket
# Processing Record 38 of Set 15 | bontang
# Processing Record 39 of Set 15 | ceyhan
# Processing Record 40 of Set 15 | nehe
# Processing Record 41 of Set 15 | puerto maldonado
# Processing Record 42 of Set 15 | ndele
# Processing Record 43 of Set 15 | arkhipo-osipovka
# Processing Record 44 of Set 15 | tiarei
# Processing Record 45 of Set 15 | funtua
# Processing Record 46 of Set 15 | barra da estiva
# Processing Record 47 of Set 15 | mahibadhoo
# Processing Record 48 of Set 15 | sug-aksy
# City not found. Skipping...
# Processing Record 49 of Set 15 | meulaboh
# Processing Record 50 of Set 15 | magadan
# Processing Record 1 of Set 16 | jardim
# Processing Record 2 of Set 16 | malanje
# Processing Record 3 of Set 16 | kamien pomorski
# Processing Record 4 of Set 16 | norsup
# Processing Record 5 of Set 16 | juba
# Processing Record 6 of Set 16 | grants pass
# Processing Record 7 of Set 16 | hoopstad
# Processing Record 8 of Set 16 | paoua
# Processing Record 9 of Set 16 | sinnamary
# Processing Record 10 of Set 16 | macaubas
# Processing Record 11 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 16 | kokopo
# Processing Record 13 of Set 16 | gazojak
# Processing Record 14 of Set 16 | koumac
# Processing Record 15 of Set 16 | isangel
# Processing Record 16 of Set 16 | vermilion
# Processing Record 17 of Set 16 | divnomorskoye
# Processing Record 18 of Set 16 | san fernando
# Processing Record 19 of Set 16 | gayeri
# Processing Record 20 of Set 16 | hovd
# Processing Record 21 of Set 16 | ouadda
# Processing Record 22 of Set 16 | toora-khem
# Processing Record 23 of Set 16 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 16 | peyima
# Processing Record 26 of Set 16 | koshurnikovo
# Processing Record 27 of Set 16 | ipixuna
# Processing Record 28 of Set 16 | karpuninskiy
# City not found. Skipping...
# Processing Record 29 of Set 16 | turbat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     53.71        40           0
# 1     Bredasdorp      ZA -34.5322   20.0403     58.28        88          73
# 2         Albany      US  42.6001  -73.9662     60.39        88          96
# 3        Ushuaia      AR -54.8000  -68.3000     51.46        50           0
# 4            Lar      IN  26.2039   83.9717     71.13        64          46
# 5    Yellowknife      CA  62.4560 -114.3525     31.41        80          40
# 6        Husavik      IS  66.0449  -17.3389     39.11        90         100
# 7        Rikitea      PF -23.1203 -134.9692     75.00        85         100
# 8      Churapcha      RU  62.0025  132.4325    -12.82       100          97
# 9  Mar Del Plata      AR -38.0023  -57.5575     64.42        77          20
#
#    Wind Speed Current Description
# 0       17.27           clear sky
# 1        2.30       broken clouds
# 2        7.94     overcast clouds
# 3       19.57           clear sky
# 4        4.14    scattered clouds
# 5        7.00    scattered clouds
# 6       16.98     overcast clouds
# 7       21.14          light rain
# 8        2.93     overcast clouds
# 9        7.00          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
